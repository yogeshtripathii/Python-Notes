# %% [markdown]
# # Theory Questions

# %% [markdown]
# 1. **What is a parameter?**
#   > Parameters are the variable of the selected model which can be estimated by fitting the given data to the model. Example- Let X is the independent variable and Y be the independent variable, then to fit the regression line the for Y value for unknow value of X, the slope(m) & the intercept (c) these parameters are estimeted by fitting the straight line by minimizing the root mean squared errro(RMSE).
#
#   ![RMSE1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 2. **What is correlation?**
#
#   > Correlation simply describes the relationship between two variables. It indicates how changes in one variable relate to changes in another. The relation can be described as:
#     * Positive Correlation
#     * Negative Correlation

# %% [markdown]
# 3. **What does negative correlation mean?**
#
#   > A negative correlation means they move in opposite directions (one increases, the other decreases) i.e they are inversaly proportional. Example- Higher the power of vehicle lower the average.

# %% [markdown]
# 4. **Define Machine Learning. What are the main components in Machine Learning?**
#
#   > It is the sub-field of computer science that gives computer the ability to learn the pattern of the data without progrmming it explicitly.
#     Compnents are data, models, training, and evaluation.
#     * Data acts as the raw material.
#     * Models are the algorithms used to learn patterns.
#     * Training involves feeding data to the model to adjust its parameters.
#     * Evaluation assesses the model's performance

# %% [markdown]
# 5. **How does loss value help in determining whether the model is good or not?**
#   > A **`loss value`** tells the error between a machine learning model's predictions and actual outcomes. A **lower loss value** indicates better performance.
#   It can be done by adjusting hyperparameters (like the learning rate), increasing training data, cleaning the data for outliers, and experimenting with different loss functions. The ultimate goal is to minimize this loss value, leading to more accurate predictions.
#
#   ![1kYrO5TZhQKGAhkc-gQDFFQ.webp](data:image/webp;base64,...)

# %% [markdown]
# 6. **What are continuous and categorical variables? How do we handle categorical variables in Machine Learning? What are the common techniques?**
#
#     * Continuous variables- These variable can take any value within a given range e.g., height, temperature.
#     * Categorical variables-  Thes evariable represent characteristics or qualities that can be grouped into distinct categories e.g., colors, gender, ship mode etc.
#
#       **Common techniques are:**
#         * **Label Encoding**- Label Encoding assigns a unique integer to each category. It's best used for ordinal categorical variables, where there is a clear order or hierarchy between the categories.
#
#         **Example**: For a variable like "T-shirt size" with categories S, M, L, and XL, you would encode them as:
#
#                   S -> 1, M -> 2, L -> 3, XL -> 4
#
#       * **One-Hot Encoding**- One-Hot Encoding creates a new binary column for each category. It is the most common technique and is ideal for nominal categorical variables, where there is no inherent order.
#
#       **Example**: For a variable like "Color" with categories Red, Blue, Green:
#
#           Red becomes [1, 0, 0]
#           Blue becomes [0, 1, 0]
#           Green becomes [0, 0, 1]
#
#       * **Dummy Encoding**- Dummy Encoding is a variation of one-hot encoding. It's a bit more efficient as it creates k-1 new columns for k categories.
#
#         **Example**: For the same "Color" variable with categories Red, Blue, Green, we can drop one category (e.g., Red) and represent it with zeros.
#
#               Red becomes [0, 0]
#               Blue becomes [1, 0]
#               Green becomes [0, 1]

# %% [markdown]
# 7. **What do you mean by training and testing a dataset?**
#   > These are the steps used to develop and evaluate the machine learning models. This process involves dividing a complete dataset into two distinct subsets:
#       * Training dataset- This subset is used to train the machine learning model. The model learns patterns, relationships, and features from this data, adjusting its internal parameters to minimize errors and optimize its performance for the specific task (e.g., classification, regression). It comprises 70-80% of overall dataset.
#       * Testing dataset- This dataset is used to evaluate the performance of the trained model on unseen data. After the model has learned from the training data, it is presented with the testing data, and its predictions are compared to the actual known outcomes in the testing set. It is smaller in portion approx 20-30%.

# %% [markdown]
# 8. **What is sklearn.preprocessing?**
#   > It is a module in scikit-learn which provides methods and transformer classes whuch are designed to prepare raw feature vectors which can be use with machine learning estimators. This process is know as data preprocessing.
#   Some fearures are :
# * **Scaling and Standardization**:
#         * StandardScaler: Removes the mean and scales to unit variance, suitable for data without significant outliers.
#         * MinMaxScaler: Scales features to a specified range, typically between 0 and 1.
#         * RobustScaler: Scales data using the median and interquartile range, making it more robust to outliers.
#         * Normalizer: Scales individual samples to have unit norm.
#
# * **Encoding Categorical Features**:
#         * OneHotEncoder: Transforms categorical features into a one-hot numerical representation.
#         * LabelEncoder: Encodes target labels with values between 0 and 1.
#         * TargetEncoder: Encodes categorical features based on the mean of the target variable for each category.
# * **Feature Transformation and Generation**:
#       * PolynomialFeatures: Generates polynomial features and interaction terms from existing features.
#       * KBinsDiscretizer: Discretizes continuous features into fixed number of bins.
#       * FunctionTransformer: Applies a custom function to transform data.
# * **Imputation of Missing Values**:
#       * SimpleImputer: Fills in missing values using strategies like mean, median, or most frequent.

# %% [markdown]
# 9. **What is a Test set?**
#   >  A test dataset is a collection of data points that the model hasn't seen during its training process.

# %% [markdown]
# 10. **How do we split data for model fitting (training and testing) in Python? How do you approach a Machine Learning problem?**
#
#   > To split data for model fitting training and testing we can use sklearn.model_selection module method train_test_split.
#
#   Approach for machine learnign problem:
#   * Define the Problem
#   * Data Collection and Exploration
#   * Data Preprocessing
#   * Model Selection
#   * Training and Evaluation
#   * Hyperparameter Tuning and Optimization
#   * Deployment and Monitoring

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split

iris = sns.load_dataset("iris")
print("Iris dataset : \n")
print(iris.head())
print(iris.shape)
X = iris.drop("species", axis=1)
y = iris["species"]

print(f"\nDatset after removing target : \n{X.head()}")
print(f"\nTarget dataset : \n{y.head()}")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# %% [markdown]
# 11. **Why do we have to perform EDA before fitting a model to the data?**
#   > EDA helps in order to check assumptions, inspect the data for anomalies (such as missing, duplicated, or mis-coded data), and inform feature selection/transformation, guide in selection of model, improved model interpretability.

# %% [markdown]
# 12. **What is correlation?**
#
#   > Correlation simply describes the relationship between two variables. It indicates how changes in one variable relate to changes in another. The relation can be described as:
#     * Positive Correlation
#     * Negative Correlation

# %% [markdown]
# 13. **What does negative correlation mean?**
#   > A negative correlation means they move in opposite directions (one increases, the other decreases) i.e they are inversaly proportional. Example- Higher the power of vehicle lower the average.

# %% [markdown]
# 14. **How can you find correlation between variables in Python?**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {'Variable_A': [10, 15, 20, 25, 30],
        'Variable_B': [2, 4, 5, 7, 8]}

df = pd.DataFrame(data)

correlation_matrix = df.corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)

sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Correlation Matrix:
#             Variable_A  Variable_B
# Variable_A    1.000000    0.993399
# Variable_B    0.993399    1.000000

# %% [markdown]
# 15. **What is causation? Explain difference between correlation and causation with an example.**
#   > Causation, or cause and effect, means that a change in one variable directly leads to a change in another variable.
#   * Examples: Turning on a light switch causes the light to turn on.
#
#   Correlation simply indicates a relationship or association between two or more variables. It can be positive (variables increase or decrease together), negative (one variable increases as the other decreases), or zero (no relationship). But it does not mean that one effect cause to change other.
#
#   **Example**- The image below shows that, if battery of laptop goes down it cause to latop shut down and also to stop the working of any software. The shutting of laptop and stopping of software is correlated but it is cause by the battery draining.
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# 16. **What is an Optimizer? What are different types of optimizers? Explain each with an example.**
#   > The optimizer is a crucial element in the learning process of the ML model. It is an algorithm that adjusts a machine learning model internal parameters (weights and biases) to minimize a loss function, which measures the error in the models predictions, thereby improving the model overall performance and accuracy.
#
#   **Types of Optimizers:**
#     * **Gradient Descent (GD)**- This is the most basic optimizer. It computes the gradient (the slope) of the loss function using the entire training dataset for each update step.
#
#       **Example**-
#       Let we have a dataset of 100,000 house prices. To update the model's weights, Gradient Descent would calculate the error for all 100,000 houses, average them, and then make one single update to the model.
#
#   * **Stochastic Gradient Descent (SGD)**- SGD is an improvement on GD. Instead of using the entire dataset, it calculates the gradient and updates the parameters using just one randomly selected data point at a time.
#
#       **Example**- For the same 100,000-house dataset, SGD would pick one house at random, calculate the error, update the weights, then pick another random house and repeat. This process is much faster.
#
#   * **Adam (Adaptive Moment Estimation)**- Adam is one of the most popular and effective optimizers today. It's an adaptive learning rate optimizer that combines the strengths of two other optimizers: RMSprop and momentum.
#   It quickly finds good weights for the millions of parameters, often without much manual hyperparameter tuning.

# %% [markdown]
# 17. **What is sklearn.linear_model ?**
#   > sklearn.linear_model is a module within the sklearn library in Python, to implement the various linear models for both regression and classification tasks. These models are based on the principle of fitting a linear combination of features to predict a target variable.
#   * **Key features and functionalities within sklearn.linear_model:**
#       * Linear Regression: This includes standard LinearRegression for basic linear regression, Ridge and Lasso for regularized linear regression
#       * Logistic Regression: LogisticRegression is used for binary and multiclass classification problems, despite its name, it's a linear model that uses a logistic function to estimate probabilities.

# %% [markdown]
# 18. **What does model.fit() do? What arguments must be given?**
#   > This method is used to train a machine learning model. During the fitting process, the model learns the patterns and relationships within the provided training data. It requires training data, usually consisting of input features (X) and corresponding target labels (Y).
#
#         model.fit() is about learning from data.

# %% [markdown]
# 19. **What does model.predict() do? What arguments must be given?**
#   > This method is used to generate predictions from a trained machine learning model on new, unseen data. It requires new input features (X) for which predictions are desired. It does not require target labels as its purpose is to generate them.
#
#         model.predict() is about applying that learning to make new inferences.

# %% [markdown]
# 20. **What are continuous and categorical variables?**
#   > **Continuous Variable**- These are the numrical variable which can be measured and have values that fall on a number line incuding fractional and decimal. Example- Height, weight Temperature, Distance etc. Types are:
#     * Interval-  Interval scales have equal intervals between values,
#      but a true zero point doesn't exist (e.g., temperature in Celsius)
#     * Ratio- Ratio scales have equal intervals and a true zero point (e.g., height, weight).
#
#   > **Categorical Variable**- These variable represent qualitative characterstics that can be grouped into different categories. Example- Gender, Education Level etc. Types are:
#     * Nominal- These are the values which do not follow any order. Example- color
#     * Ordinal- These are the values which have order or rank. Example- size  (small < medium < large < xL)

# %% [markdown]
# 21. **What is feature scaling? How does it help in Machine Learning?**
#   > Feature scaling is the process in which we tries to bring all the features on the same scale or range.
#
#   * **Normalization (Min-Max Scaling)**: This method scales features to a specific range, typically between 0 and 1.
#         Formula:
#           X_scaled = (X - X_min) / (X_max - X_min)
#   * **Standardization (Z-score Normalization)**: This method transforms features to have a mean of 0 and a standard deviation of 1.
#           Forumla:
#                 X_scaled = (X - μ) / σ

# %% [markdown]
# 22. **How do we perform scaling in Python?**
#   > To perfrom feature scaling we can use the sklearn.preprocessing module and used the specific scaling method like StandardScaler, Normalizer etc.

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

data = {'Feature1': [10, 20, 30, 40, 50],
        'Feature2': [100, 200, 300, 400, 500]}
df = pd.DataFrame(data)
print(df)

scaler = StandardScaler()

scaled_data = scaler.fit_transform(df)

print(scaled_data)
# Out:
#    Feature1  Feature2
# 0        10       100
# 1        20       200
# 2        30       300
# 3        40       400
# 4        50       500
# [[-1.41421356 -1.41421356]
#  [-0.70710678 -0.70710678]
#  [ 0.          0.        ]
#  [ 0.70710678  0.70710678]
#  [ 1.41421356  1.41421356]]
#    Feature1  Feature2
# 0 -1.414214 -1.414214
# 1 -0.707107 -0.707107
# 2  0.000000  0.000000
# 3  0.707107  0.707107
# 4  1.414214  1.414214

# %% [markdown]
# 23. **What is sklearn.preprocessing?**
#   > It is a module in scikit-learn which provides methods and transformer classes whuch are designed to prepare raw feature vectors which can be use with machine learning estimators. This process is know as data preprocessing.
#   Some fearures are :
# * **Scaling and Standardization**:
#         * StandardScaler: Removes the mean and scales to unit variance, suitable for data without significant outliers.
#         * MinMaxScaler: Scales features to a specified range, typically between 0 and 1.
#         * RobustScaler: Scales data using the median and interquartile range, making it more robust to outliers.
#         * Normalizer: Scales individual samples to have unit norm.
#
# * **Encoding Categorical Features**:
#         * OneHotEncoder: Transforms categorical features into a one-hot numerical representation.
#         * LabelEncoder: Encodes target labels with values between 0 and 1.
#         * TargetEncoder: Encodes categorical features based on the mean of the target variable for each category.
# * **Feature Transformation and Generation**:
#       * PolynomialFeatures: Generates polynomial features and interaction terms from existing features.
#       * KBinsDiscretizer: Discretizes continuous features into fixed number of bins.
#       * FunctionTransformer: Applies a custom function to transform data.
# * **Imputation of Missing Values**:
#       * SimpleImputer: Fills in missing values using strategies like mean, median, or most frequent.

# %% [markdown]
# 24. **How do we split data for model fitting (training and testing) in Python?**

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split

iris = sns.load_dataset("iris")
print("Iris dataset : \n")
print(iris.head())
print(iris.shape)
X = iris.drop("species", axis=1)
y = iris["species"]

print(f"\nDatset after removing target : \n{X.head()}")
print(f"\nTarget dataset : \n{y.head()}")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# Iris dataset :
#
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# (150, 5)
#
# Datset after removing target :
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
#
# Target dataset :
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object
# (120, 4) (30, 4) (120,) (30,)

# %% [markdown]
# 25. **Explain data encoding?**
#   > Data encoding is the process of converting data from one format or structure to another. Simply means, it is used to handle categorical data, which represents labels or categories rather than numerical values. Most machine learning algorithms are designed to work with numerical input.
#
#   > **Ways to do data encoding**:
#     * **Label Encoding**: Assigns a unique integer to each category. For example, "red" might be 0, "green" 1, and "blue" 2. .
#     * **One-Hot Encoding**: Transforms each category into a binary vector. For a categorical feature with 'n' unique categories, it creates 'n' new binary columns. For example, if "color" has "red," "green," and "blue," one-hot encoding creates three columns: is_red, is_green, and is_blue, with a '1' in the corresponding column and '0' in others.
#     * **Ordinal Encoding**: Used for ordinal data, where categories have a natural order (e.g., "low," "medium," "high"). It assigns numerical values that reflect this order (e.g., "low" = 1, "medium" = 2, "high" = 3).
#     * **Target Encoding**: Replaces each category with a statistical measure of the target variable for that category (e.g., the mean of the target variable for all instances belonging to that category).
