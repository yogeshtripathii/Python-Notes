# %% [markdown]
# # **Theory + Practical**

# %% [markdown]
# **Question 1: What is Simple Linear Regression?**
#   > Simple linear regression is a type of regression when we want to predict a target value using only one input feature. It assumes a straight-line relationship between the two. It is given as:
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 2: What are the key assumptions of Simple Linear Regression?**
#   > Assumption for linear regressions:
#   > 1. **Linearity:** The relationship between inputs (X) and the output (Y) is a straight line.
#   > 2. **Independence of Errors:** The errors in predictions should not affect each other.
#   >3. **Constant Variance (Homoscedasticity):** The errors should have equal spread across all values of the input. If the spread changes, it's called heteroscedasticity and it's a problem for the model.
#   >4. **Normality of Errors:** The errors should follow a normal (bell-shaped) distribution.
#   >5. **No Multicollinearity(for multiple regression):** Input variables shouldn’t be too closely related to each other.
#   >6. **No Autocorrelation:** Errors shouldn't show repeating patterns, especially in time-based data.
#   >7. **Additivity:** The total effect on Y is just the sum of effects from each X, no mixing or interaction between them.'

# %% [markdown]
# **Question 3: What is heteroscedasticity, and why is it important to address in regression models?**
#
#   > During the linear regression model we make some assumptions like:
#   >1. Error has zero mean
#   >2. Error has constant variance
#   >3. Errors are uncorrelated
#   >4. Errors are normally distributed
#
#   If the varinace of error is constant than we say it homoscedasity but on voilating it it become heteroscedasticity.
#
#   In simple words, if the variance of error does not remain same to each value and varies then it heteroscedasticity and with this the estimater ar enot longer best to estimate the datav points. As we cna see in the below image, in case of homoscedasticity, the data points are equally scattered while in case of heteroscedasticity the data points are not equally scattered.
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 4: What is Multiple Linear Regression?**
#   > Multiple linear regression involves more than one independent variable and one dependent variable. The equation for multiple linear regression is:
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 5: What is polynomial regression, and how does it differ from linear regression?**
#   > Polynomial Regression is a form of linear regression where the relationship between the independent variable (x) and the dependent variable (y) is modelled as an n degree polynomial. It is useful when the data exhibits a non-linear relationship or curved relationship.
#
#   On other hand linear regression model has straight line relationship between 2 variables.
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 6: Implement a Python program to fit a Simple Linear Regression model to the following sample data:**
#
#       X = [1, 2, 3, 4, 5]
#       Y = [2.1, 4.3, 6.1, 7.9, 10.2]
# Plot the regression line over the data points.

# %%
# Implement a Python program to fit a Simple Linear Regression model to the following sample data:

X = [1, 2, 3, 4, 5]
Y = [2.1, 4.3, 6.1, 7.9, 10.2]

import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X = np.array(X).reshape(-1, 1)
Y = np.array(Y)

model = LinearRegression()
model.fit(X, Y)

Y_pred = model.predict(X)
print(Y_pred)

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Linear Regression')
plt.show()
# Out:
# [ 2.16  4.14  6.12  8.1  10.08]

# %% [markdown]
# **Question 7: Fit a Multiple Linear Regression model on this sample data:**
#
#       Area = [1200, 1500, 1800, 2000]
#       Rooms = [2, 3, 3, 4]
#       Price = [250000, 300000, 320000, 370000]
# Check for multicollinearity using VIF and report the results.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor

Area = [1200, 1500, 1800, 2000]
Rooms = [2, 3, 3, 4]
Price = [250000, 300000, 320000, 370000]

X = np.array([Area, Rooms]).reshape(-1,2)
Y = np.array(Price)

model = LinearRegression()
model.fit(X, Y)

Y_pred = model.predict(X)
print(Y_pred)

vif = [variance_inflation_factor(X, i) for i in range(X.shape[1])]
print(vif)
# Out:
# [249983.37561906 300024.97834121 344986.69516683 345004.95087291]
# [np.float64(324.98830050048383), np.float64(324.98830050048383)]

# %% [markdown]
# **Question 8: Implement polynomial regression on the following data:**
#
#     X = [1, 2, 3, 4, 5]
#     Y = [2.2, 4.8, 7.5, 11.2, 14.7]
#
# Fit a 2nd-degree polynomial and plot the resulting curve.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([2.2, 4.8, 7.5, 11.2, 14.7])

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, Y)

Y_pred = model.predict(X_poly)

print("Predicted values:", Y_pred)

plt.scatter(X, Y, label="Data points")
plt.plot(X, Y_pred, color='red', label="Polynomial fit")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Polynomial Regression (degree=2)")
plt.legend()
plt.show()
# Out:
# Predicted values: [ 2.2   4.74  7.68 11.02 14.76]

# %% [markdown]
# **Question 9: Create a residuals plot for a regression model trained on this data:**
#
#     X = [10, 20, 30, 40, 50]
#     Y = [15, 35, 40, 50, 65]
# Assess heteroscedasticity by examining the spread of residuals.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

X = np.array([10, 20, 30, 40, 50]).reshape(-1, 1)
Y = np.array([15, 35, 40, 50, 65])

model = LinearRegression()
model.fit(X, Y)

Y_pred = model.predict(X)

residuals = Y - Y_pred

plt.scatter(Y_pred, residuals, color="blue")
plt.axhline(y=0, color="red", linestyle="--")  # reference line at 0
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residuals Plot")
plt.show()

# %% [markdown]
# **Question 10: Imagine you are a data scientist working for a real estate company. You need to predict house prices using features like area, number of rooms, and location. However, you detect heteroscedasticity and multicollinearity in your regression model. Explain the steps you would take to address these issues and ensure a robust model**.
#
# > **Handling Heteroscedasticity:**
# 1. Transform the target variable e.g., apply log,square root.
#
# 2. Weighted Least Squares (WLS): give less weight to data points with higher variance.
#
# 3. Robust regression (e.g., HuberRegressor in scikit-learn) to reduce sensitivity to unequal error variance
#
# > **Handling Multicollinearity:**
# 1. Check correlations / VIF (Variance Inflation Factor): identify highly correlated predictors (e.g., area and number of rooms).
#
# 2. Remove or combine features: drop redundant variables or combine them (e.g., total area per room).
#
# 3. Regularization: use Ridge or Lasso regression, which penalize large coefficients and stabilize the model.
